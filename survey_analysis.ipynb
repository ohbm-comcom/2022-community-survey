# %%
# import some packages for reading/writing, plotting and statistics

import json
import warnings

import numpy             as np
import pandas            as pd
import seaborn           as sns
import matplotlib.pyplot as plt

from itertools                            import zip_longest
from patsy.contrasts                      import Treatment
from pandas.api.types                     import CategoricalDtype
from statsmodels.miscmodels.ordinal_model import OrderedModel

sns.set                 ( context = 'talk', style = 'white' )
plt.rcParams.update     ( {'font.size': 16}                 )
warnings.filterwarnings ( 'ignore'                          )

# %%
# functions for analysis 

def fit_model(responses, query, levels):
    """
    Fit an ordinal logistic model to the Likert response data.

    You can find more information on this model in the StatsModels documentation:
    https://www.statsmodels.org/dev/generated/statsmodels.miscmodels.ordinal_model.OrderedModel.html

    Parameters
    ----------
    responses : pd.DataFrame
        Survey responses data, loaded as a Pandas DataFrame and coerced
        into the appropriate format.
    query : str
        The query for which to fit a model. Possible query values are defined
        in the `rename_questions` mapping.
    levels : list
        A query specific list of possible participant Likert responses, listed
        in ordinal ranking.
    """
    # first, subset the full data frame
    data = responses.query(f'question == \"{query}\"')
    data.dropna(inplace=True)

    # then, define the response levels as ordered
    cat = CategoricalDtype(categories=levels, ordered=True)
    data[f'{query}'] = data.response.astype(cat, copy=False)

    # and fit and return the model
    mod = OrderedModel.from_formula(
        f'{query} ~ 1 + C(geographic_region, Treatment) + C(career_stage, Treatment)',
        data=data)
    res = mod.fit(method='bfgs')
    return res

def format_data(survey_data_path):
    """
    Load in the data. This spreadsheet is (almost) direct from SurveyMonkey,
    though IP addresses, access dates, and free-text responses were scrubbed
    to anonymize respondents.
    """

    df = pd.read_csv(survey_data_path, sep=',', index_col='Unnamed: 0')

    # SurveyMonkey provides an odd nesting of responses when exporting results.
    # We'd like to convert this structure to a pandas MultiIndex data frame.
    # First, let's find question indices -- adapted from https://stackoverflow.com/a/49584888

    indices = [i for i, c in enumerate(df.columns) if not c.startswith('Unnamed')]
    repeats = [len(df.columns[i:j]) for i, j in zip_longest(indices, indices[1:])]

    # We can pair each possible response with its associated question...
    matched_questions = []
    for question, n_rep in zip(df.columns[indices], repeats):
        matched_questions += [question] * n_rep

    df.columns = matched_questions
    df.index.name = 'participant_id'

    # Now we'll rename our columns to ease analysis--
    demographics = {
        'Are you a member of OHBM?': 'is_member',
        'What geographic region are you currently located in?': 'geographic_region',
        'What is your current career status?': 'career_stage'
    }
    rename_questions = {
        'How would you describe your access to the OHBM job board?': 'job_board_access',
        'How would you describe the content on the OHBM job board?': 'job_board_content',
        'How would you describe your access to emails from OHBM?': 'email_access',
        'How would you describe the content in OHBM emails?': 'email_content',
        'How would you describe your access to the OHBM blog?': 'blog_access',
        'How would you describe the content in the OHBM blog?': 'blog_content',
        'How would you describe your access to OHBM Twitter?': 'twitter_access',
        'How would you describe the content on OHBM Twitter?': 'twitter_content',
        'How would you describe your access to the NeuroSalience podcast?': 'podcast_access',
        'How would you describe the content in the NeuroSalience podcast?': 'podcast_content',
        'How would you describe your access to OHBM Facebook?': 'facebook_access',
        'How would you describe the content in OHBM Facebook?': 'facebook_content',
        'How would you describe your access to OHBM YouTube?': 'youtube_access',
        'How would you describe the content in OHBM YouTube?': 'youtube_content',
        'How would you describe your access to OHBM LinkedIn?': 'linkedin_access',
        'How would you describe the content in OHBM LinkedIn?': 'linkedin_content',
        'How would you describe your access to the OHBM OnDemand?': 'ondemand_access',
        'How would you describe the content in OHBM OnDemand?': 'ondemand_content',
        'Which of the following platforms do you use to access OHBM content? When applicable, a direct link to the platform is provided next to each option. Please check all options that apply.': 'content_platform',
        'Do you currently follow any of the following OHBM Special Interest Groups (SIG) platforms? When applicable, a direct link to the platform is provided next to each option. Please check all options that apply.': 'sig_platform',
        'How important is each of these types of content to you?': 'content_importance'
    }

    responses = pd.melt(
        df.iloc[1:].reset_index().rename({**demographics, **rename_questions}, axis=1), 
        id_vars=['participant_id'] + list(demographics.values()), 
        value_name='response', 
        var_name='question'
    )

    # We'll need to set up a coding scheme for our demographic data
    responses['is_member'] = responses.is_member.astype(bool)
    responses['geographic_region'] = responses.geographic_region.astype('category')
    responses['career_stage'] = responses.career_stage.astype('category')

    return responses

# %%
responses = format_data('public_survey_data.csv')

# now let's run some basic analyses to check against SurveyMonkey outputs
responses['is_member'].value_counts(normalize=True)
responses['geographic_region'].value_counts(normalize=True)
responses['career_stage'].value_counts(normalize=True)

# load in our JSON with question-level metadata for available responses
with open('levels.json') as f:
     queries = json.load(f)

for q in queries:
    levels = queries[q]
    print(f'Now fitting a model for {q}....')
    res = fit_model(responses, q, levels)
    print(res.summary())
    print(np.exp(res.params))  # odds ratios
    print()

# FIXME: facebook_access
# ValueError: zero-size array to reduction operation maximum which has no identity
    # "facebook_access" : [
    #     "I don’t use Facebook / NA",
    #     "I use Facebook but didn’t know that the OHBM Facebook page exists",
    #     "I use Facebook and know about the OHBM Facebook page, but I don’t follow/like the page",
    #     "I use Facebook, follow/like the page, and occasionally see their posts",
    #     "I use Facebook, follow/like the page, and regularly see their posts"
    # ],
# Out:
# Now fitting a model for job_board_access....
# Optimization terminated successfully.
#          Current function value: 1.071704
#          Iterations: 56
#          Function evaluations: 57
#          Gradient evaluations: 57
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:       job_board_access   Log-Likelihood:                -327.94
# Model:                   OrderedModel   AIC:                             685.9
# Method:            Maximum Likelihood   BIC:                             741.7
# Date:                Fri, 19 Jan 2024
# Time:                        14:56:33
# No. Observations:                 306
# Df Residuals:                     291
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                               -0.2405      0.212     -1.135      0.256      -0.656       0.175
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          -0.3899      0.658     -0.593      0.554      -1.680       0.900
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          -0.2695      0.217     -1.240      0.215      -0.696       0.157
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.5670      0.414      1.370      0.171      -0.244       1.378
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             1.1642      0.466      2.499      0.012       0.251       2.077
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.9569      0.230      4.160      0.000       0.506       1.408
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        1.1112      0.190      5.857      0.000       0.739       1.483
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.3992      0.457     -0.874      0.382      -1.295       0.496
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.6375      0.430      1.481      0.139      -0.206       1.481
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.6488      0.213      3.041      0.002       0.231       1.067
# C(career_stage, Treatment)[T.Research staff]                                                                                                             1.0834      0.250      4.325      0.000       0.592       1.574
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.1790      0.565      0.317      0.751      -0.928       1.286
# I didn't know OHBM had a job board/I know about the OHBM job board but I don't use it                                                                    0.2900      0.227      1.275      0.202      -0.156       0.736
# I know about the OHBM job board but I don't use it/I look at the OHBM job board ocassionally                                                            -0.0510      0.088     -0.581      0.561      -0.223       0.121
# I look at the OHBM job board ocassionally/I look at the OHBM job board regularly                                                                         0.2799      0.117      2.382      0.017       0.050       0.510
# ========================================================================================================================================================================================================================
# C(geographic_region, Treatment)[T.Europe]                                                                                                               0.786201
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          0.677140
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          0.763783
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  1.762953
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            3.203366
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    2.603727
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       3.037903
# C(career_stage, Treatment)[T.Masters student]                                                                                                           0.670856
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     1.891757
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   1.913315
# C(career_stage, Treatment)[T.Research staff]                                                                                                            2.954613
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     1.196012
# I didn't know OHBM had a job board/I know about the OHBM job board but I don't use it                                                                   1.336405
# I know about the OHBM job board but I don't use it/I look at the OHBM job board ocassionally                                                            0.950279
# I look at the OHBM job board ocassionally/I look at the OHBM job board regularly                                                                        1.322980
# dtype: float64
#
# Now fitting a model for job_board_content....
# Optimization terminated successfully.
#          Current function value: 1.151657
#          Iterations: 62
#          Function evaluations: 63
#          Gradient evaluations: 63
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:      job_board_content   Log-Likelihood:                -263.73
# Model:                   OrderedModel   AIC:                             557.5
# Method:            Maximum Likelihood   BIC:                             609.0
# Date:                Fri, 19 Jan 2024
# Time:                        14:56:34
# No. Observations:                 229
# Df Residuals:                     214
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                               -0.1121      0.232     -0.483      0.629      -0.567       0.343
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          -0.6107      0.634     -0.963      0.335      -1.853       0.632
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.1100      0.235      0.468      0.640      -0.351       0.571
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.6696      0.500      1.338      0.181      -0.311       1.650
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.9207      0.600      1.534      0.125      -0.256       2.097
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    -0.5024      0.254     -1.976      0.048      -1.001      -0.004
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       -0.5042      0.207     -2.435      0.015      -0.910      -0.098
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.6856      0.519     -1.322      0.186      -1.702       0.331
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     -0.7151      0.439     -1.629      0.103      -1.576       0.145
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   -0.2466      0.245     -1.006      0.314      -0.727       0.234
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.3419      0.270     -1.265      0.206      -0.872       0.188
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     -1.6168      0.705     -2.295      0.022      -2.998      -0.236
# Postings are not relevant to me/Postings are somewhat relevant                                                                                          -0.9180      0.246     -3.725      0.000      -1.401      -0.435
# Postings are somewhat relevant/Postings are relevant when related to the Annual Meeting                                                                  0.3037      0.080      3.795      0.000       0.147       0.461
# Postings are relevant when related to the Annual Meeting/Postings are very relevant throughout the year                                                 -1.2616      0.231     -5.452      0.000      -1.715      -0.808
# ========================================================================================================================================================================================================================
# C(geographic_region, Treatment)[T.Europe]                                                                                                               0.893946
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          0.542957
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          1.116283
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  1.953475
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            2.511046
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    0.605049
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       0.604007
# C(career_stage, Treatment)[T.Masters student]                                                                                                           0.503775
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     0.489142
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   0.781444
# C(career_stage, Treatment)[T.Research staff]                                                                                                            0.710386
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     0.198541
# Postings are not relevant to me/Postings are somewhat relevant                                                                                          0.399308
# Postings are somewhat relevant/Postings are relevant when related to the Annual Meeting                                                                 1.354904
# Postings are relevant when related to the Annual Meeting/Postings are very relevant throughout the year                                                 0.283191
# dtype: float64
#
# Now fitting a model for email_access....
# Optimization terminated successfully.
#          Current function value: 0.835409
#          Iterations: 63
#          Function evaluations: 64
#          Gradient evaluations: 64
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:           email_access   Log-Likelihood:                -257.31
# Model:                   OrderedModel   AIC:                             544.6
# Method:            Maximum Likelihood   BIC:                             600.6
# Date:                Fri, 19 Jan 2024
# Time:                        14:56:35
# No. Observations:                 308
# Df Residuals:                     293
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.0250      0.228      0.110      0.913      -0.423       0.473
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           1.1968      0.782      1.531      0.126      -0.335       2.729
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          -0.4590      0.233     -1.972      0.049      -0.915      -0.003
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.6711      0.489      1.373      0.170      -0.287       1.629
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.8471      0.533      1.589      0.112      -0.198       1.892
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.0408      0.233      0.175      0.861      -0.417       0.498
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.5257      0.193      2.718      0.007       0.147       0.905
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.8490      0.431     -1.971      0.049      -1.693      -0.005
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.3917      0.458      0.855      0.393      -0.507       1.290
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.2685      0.210      1.279      0.201      -0.143       0.680
# C(career_stage, Treatment)[T.Research staff]                                                                                                             0.6218      0.267      2.331      0.020       0.099       1.145
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.2835      0.532      0.533      0.594      -0.759       1.326
# I don't get emails from OHBM/I get emails from OHBM but I don't read them                                                                               -1.7037      0.257     -6.627      0.000      -2.208      -1.200
# I get emails from OHBM but I don't read them/I get emails from OHBM and I occasionally read them                                                        -2.2766      0.568     -4.005      0.000      -3.391      -1.163
# I get emails from OHBM and I occasionally read them/I get emails from OHBM and I always read them                                                        0.6145      0.073      8.407      0.000       0.471       0.758
# ========================================================================================================================================================================================================================
# C(geographic_region, Treatment)[T.Europe]                                                                                                               1.025341
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          3.309348
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          0.631941
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  1.956297
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            2.332902
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    1.041602
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       1.691666
# C(career_stage, Treatment)[T.Masters student]                                                                                                           0.427851
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     1.479443
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   1.308018
# C(career_stage, Treatment)[T.Research staff]                                                                                                            1.862280
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     1.327802
# I don't get emails from OHBM/I get emails from OHBM but I don't read them                                                                               0.182005
# I get emails from OHBM but I don't read them/I get emails from OHBM and I occasionally read them                                                        0.102629
# I get emails from OHBM and I occasionally read them/I get emails from OHBM and I always read them                                                       1.848783
# dtype: float64
#
# Now fitting a model for email_content....
# Optimization terminated successfully.
#          Current function value: 1.274311
#          Iterations: 53
#          Function evaluations: 54
#          Gradient evaluations: 54
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:          email_content   Log-Likelihood:                -391.21
# Model:                   OrderedModel   AIC:                             814.4
# Method:            Maximum Likelihood   BIC:                             874.1
# Date:                Fri, 19 Jan 2024
# Time:                        14:56:36
# No. Observations:                 307
# Df Residuals:                     291
# Df Model:                          16
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.1884      0.204      0.922      0.357      -0.212       0.589
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.0313      0.577      0.054      0.957      -1.099       1.162
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.0739      0.210      0.352      0.725      -0.337       0.485
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  -0.0982      0.404     -0.243      0.808      -0.891       0.694
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.7402      0.449      1.647      0.100      -0.141       1.621
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    -0.0300      0.216     -0.139      0.889      -0.453       0.393
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.3437      0.174      1.970      0.049       0.002       0.686
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.4968      0.392     -1.266      0.206      -1.266       0.272
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.0436      0.406      0.107      0.914      -0.752       0.839
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.2160      0.192      1.125      0.261      -0.160       0.592
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.0051      0.235     -0.022      0.983      -0.466       0.455
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     -0.4942      0.503     -0.982      0.326      -1.480       0.492
# I don’t know / NA/It is not relevant to me                                                                                                              -1.3348      0.230     -5.807      0.000      -1.785      -0.884
# It is not relevant to me/It is somewhat relevant                                                                                                        -1.7909      0.368     -4.864      0.000      -2.513      -1.069
# It is somewhat relevant/It is very relevant only when related to the annual meeting                                                                      0.4065      0.073      5.538      0.000       0.263       0.550
# It is very relevant only when related to the annual meeting/It is very relevant throughout the year                                                     -0.3377      0.103     -3.291      0.001      -0.539      -0.137
# ========================================================================================================================================================================================================================
# C(geographic_region, Treatment)[T.Europe]                                                                                                               1.207330
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          1.031798
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          1.076703
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  0.906432
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            2.096388
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    0.970407
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       1.410176
# C(career_stage, Treatment)[T.Masters student]                                                                                                           0.608502
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     1.044585
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   1.241123
# C(career_stage, Treatment)[T.Research staff]                                                                                                            0.994959
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     0.610068
# I don’t know / NA/It is not relevant to me                                                                                                              0.263218
# It is not relevant to me/It is somewhat relevant                                                                                                        0.166816
# It is somewhat relevant/It is very relevant only when related to the annual meeting                                                                     1.501580
# It is very relevant only when related to the annual meeting/It is very relevant throughout the year                                                     0.713434
# dtype: float64
#
# Now fitting a model for blog_access....
# Optimization terminated successfully.
#          Current function value: 1.092577
#          Iterations: 52
#          Function evaluations: 53
#          Gradient evaluations: 53
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:            blog_access   Log-Likelihood:                -331.05
# Model:                   OrderedModel   AIC:                             692.1
# Method:            Maximum Likelihood   BIC:                             747.8
# Date:                Fri, 19 Jan 2024
# Time:                        14:56:37
# No. Observations:                 303
# Df Residuals:                     288
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                               -0.1677      0.217     -0.773      0.439      -0.593       0.257
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.5422      0.609      0.890      0.374      -0.652       1.737
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          -0.0451      0.222     -0.204      0.839      -0.479       0.389
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.0589      0.423      0.139      0.889      -0.770       0.888
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            -0.1372      0.479     -0.287      0.774      -1.075       0.801
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.7578      0.231      3.280      0.001       0.305       1.211
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.7726      0.191      4.048      0.000       0.399       1.147
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.2320      0.457     -0.508      0.611      -1.127       0.663
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.2225      0.445      0.501      0.617      -0.649       1.094
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.7866      0.212      3.711      0.000       0.371       1.202
# C(career_stage, Treatment)[T.Research staff]                                                                                                             0.6321      0.258      2.454      0.014       0.127       1.137
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.1851      0.569      0.325      0.745      -0.930       1.300
# I didn't know that OHBM had a blog/I know about the blog, but I don’t read it                                                                            0.4042      0.234      1.728      0.084      -0.054       0.863
# I know about the blog, but I don’t read it/I know about the blog and occasionally read the posts                                                        -0.3801      0.105     -3.625      0.000      -0.586      -0.175
# I know about the blog and occasionally read the posts/I know about the blog and regularly read the posts                                                 0.2521      0.114      2.215      0.027       0.029       0.475
# ========================================================================================================================================================================================================================
# C(geographic_region, Treatment)[T.Europe]                                                                                                               0.845606
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          1.719761
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          0.955857
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  1.060670
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            0.871763
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    2.133655
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       2.165380
# C(career_stage, Treatment)[T.Masters student]                                                                                                           0.792969
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     1.249244
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   2.195991
# C(career_stage, Treatment)[T.Research staff]                                                                                                            1.881576
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     1.203301
# I didn't know that OHBM had a blog/I know about the blog, but I don’t read it                                                                           1.498127
# I know about the blog, but I don’t read it/I know about the blog and occasionally read the posts                                                        0.683814
# I know about the blog and occasionally read the posts/I know about the blog and regularly read the posts                                                1.286764
# dtype: float64
#
# Now fitting a model for blog_content....
# Optimization terminated successfully.
#          Current function value: 0.912506
#          Iterations: 63
#          Function evaluations: 64
#          Gradient evaluations: 64
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:           blog_content   Log-Likelihood:                -271.01
# Model:                   OrderedModel   AIC:                             574.0
# Method:            Maximum Likelihood   BIC:                             633.1
# Date:                Fri, 19 Jan 2024
# Time:                        14:56:38
# No. Observations:                 297
# Df Residuals:                     281
# Df Model:                          16
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.0277      0.247      0.112      0.911      -0.457       0.512
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.2290      0.709      0.323      0.747      -1.160       1.618
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.2473      0.247      1.001      0.317      -0.237       0.732
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.1570      0.496      0.317      0.752      -0.815       1.129
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            -0.2083      0.609     -0.342      0.732      -1.401       0.984
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.6872      0.259      2.649      0.008       0.179       1.196
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.6723      0.217      3.095      0.002       0.247       1.098
# C(career_stage, Treatment)[T.Masters student]                                                                                                            0.1340      0.507      0.264      0.792      -0.860       1.128
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.5247      0.458      1.145      0.252      -0.374       1.423
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.5922      0.240      2.470      0.014       0.122       1.062
# C(career_stage, Treatment)[T.Research staff]                                                                                                             0.5153      0.280      1.840      0.066      -0.034       1.064
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.1047      0.670      0.156      0.876      -1.209       1.419
# I don’t know / NA/It is not relevant to me                                                                                                               1.0284      0.266      3.865      0.000       0.507       1.550
# It is not relevant to me/It is somewhat relevant                                                                                                        -2.6715      0.373     -7.162      0.000      -3.403      -1.940
# It is somewhat relevant/It is very relevant only when related to the annual meeting                                                                     -0.4128      0.127     -3.254      0.001      -0.661      -0.164
# It is very relevant only when related to the annual meeting/It is very relevant throughout the year                                                     -3.3241      0.703     -4.731      0.000      -4.701      -1.947
# ========================================================================================================================================================================================================================
# C(geographic_region, Treatment)[T.Europe]                                                                                                               1.028038
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          1.257314
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          1.280519
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  1.169942
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            0.811937
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    1.988087
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       1.958640
# C(career_stage, Treatment)[T.Masters student]                                                                                                           1.143382
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     1.689968
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   1.808039
# C(career_stage, Treatment)[T.Research staff]                                                                                                            1.674124
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     1.110414
# I don’t know / NA/It is not relevant to me                                                                                                              2.796625
# It is not relevant to me/It is somewhat relevant                                                                                                        0.069150
# It is somewhat relevant/It is very relevant only when related to the annual meeting                                                                     0.661804
# It is very relevant only when related to the annual meeting/It is very relevant throughout the year                                                     0.036006
# dtype: float64
#
# Now fitting a model for twitter_access....
# Optimization terminated successfully.
#          Current function value: 1.267502
#          Iterations: 68
#          Function evaluations: 69
#          Gradient evaluations: 69
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:         twitter_access   Log-Likelihood:                -385.32
# Model:                   OrderedModel   AIC:                             802.6
# Method:            Maximum Likelihood   BIC:                             862.1
# Date:                Fri, 19 Jan 2024
# Time:                        14:56:39
# No. Observations:                 304
# Df Residuals:                     288
# Df Model:                          16
# ====================================================================================================================================================================================================================================
#                                                                                                                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.1803      0.352      0.512      0.609      -0.510       0.871
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            -0.3050      0.455     -0.670      0.503      -1.197       0.587
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.0865      0.220      0.394      0.693      -0.344       0.517
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.0757      0.206      0.368      0.713      -0.328       0.480
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.1338      0.423     -0.316      0.752      -0.964       0.696
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     -0.3045      0.786     -0.387      0.699      -1.845       1.236
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.1079      0.178      0.606      0.544      -0.241       0.457
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.1731      0.299     -0.578      0.563      -0.760       0.414
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      1.0367      0.765      1.356      0.175      -0.462       2.535
# BrainArt Twitter (https://twitter.com/OHBM_BrainArt)/BrainArt Instagram (https://www.instagram.com/ohbm_basig)                                          -0.7084      0.271     -2.615      0.009      -1.239      -0.178
# BrainArt Instagram (https://www.instagram.com/ohbm_basig)/Open Science Twitter (https://twitter.com/OhbmOpen)                                           -1.8001      0.259     -6.938      0.000      -2.309      -1.292
# Open Science Twitter (https://twitter.com/OhbmOpen)/Student-Postdoc Blog (https://www.ohbmtrainees.com/sig-blog)                                        -0.2967      0.101     -2.938      0.003      -0.495      -0.099
# Student-Postdoc Blog (https://www.ohbmtrainees.com/sig-blog)/Student-Postdoc Facebook (https://www.facebook.com/OHBMStudentandPostdocSection)           -1.5390      0.200     -7.683      0.000      -1.932      -1.146
# Student-Postdoc Facebook (https://www.facebook.com/OHBMStudentandPostdocSection)/Student-Postdoc Twitter (https://twitter.com/OHBM_Trainees)            -2.8466      0.404     -7.050      0.000      -3.638      -2.055
# Student-Postdoc Twitter (https://twitter.com/OHBM_Trainees)/Sustainability Blog (https://ohbm-environment.org/blog)                                     -0.3727      0.119     -3.133      0.002      -0.606      -0.140
# Sustainability Blog (https://ohbm-environment.org/blog)/Sustainability Twitter (https://twitter.com/OhbmEnvironment)                                    -1.7549      0.307     -5.711      0.000      -2.357      -1.153
# ========================================================================================================================================================================================================================
# C(geographic_region, Treatment)[T.Europe]                                                                                                               1.004196
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          1.844242
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          1.101498
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  1.197594
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            0.737138
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    1.090365
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       1.078675
# C(career_stage, Treatment)[T.Masters student]                                                                                                           0.874788
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     0.737494
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   1.113983
# C(career_stage, Treatment)[T.Research staff]                                                                                                            0.841014
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     2.819859
# BrainArt Twitter (https://twitter.com/OHBM_BrainArt)/BrainArt Instagram (https://www.instagram.com/ohbm_basig)                                          0.492431
# BrainArt Instagram (https://www.instagram.com/ohbm_basig)/Open Science Twitter (https://twitter.com/OhbmOpen)                                           0.165287
# Open Science Twitter (https://twitter.com/OhbmOpen)/Student-Postdoc Blog (https://www.ohbmtrainees.com/sig-blog)                                        0.743256
# Student-Postdoc Blog (https://www.ohbmtrainees.com/sig-blog)/Student-Postdoc Facebook (https://www.facebook.com/OHBMStudentandPostdocSection)           0.214588
# Student-Postdoc Facebook (https://www.facebook.com/OHBMStudentandPostdocSection)/Student-Postdoc Twitter (https://twitter.com/OHBM_Trainees)            0.058041
# Student-Postdoc Twitter (https://twitter.com/OHBM_Trainees)/Sustainability Blog (https://ohbm-environment.org/blog)                                     0.688856
# Sustainability Blog (https://ohbm-environment.org/blog)/Sustainability Twitter (https://twitter.com/OhbmEnvironment)                                    0.172921
# dtype: float64
#
# Now fitting a model for content_importance....
# Optimization terminated successfully.
#          Current function value: 2.012973
#          Iterations: 64
#          Function evaluations: 65
#          Gradient evaluations: 65
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:     content_importance   Log-Likelihood:                -2375.3
# Model:                   OrderedModel   AIC:                             4789.
# Method:            Maximum Likelihood   BIC:                             4885.
# Date:                Fri, 19 Jan 2024
# Time:                        14:56:59
# No. Observations:                1180
# Df Residuals:                    1161
# Df Model:                          19
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.1614      0.119      1.357      0.175      -0.072       0.394
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.5800      0.312      1.857      0.063      -0.032       1.192
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.1422      0.119      1.193      0.233      -0.091       0.376
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.2195      0.182      1.207      0.227      -0.137       0.576
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.1309      0.220      0.594      0.552      -0.301       0.562
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    -0.0765      0.105     -0.727      0.467      -0.283       0.130
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       -0.0720      0.085     -0.846      0.397      -0.239       0.095
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.0117      0.208     -0.056      0.955      -0.420       0.397
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     -0.2561      0.205     -1.251      0.211      -0.657       0.145
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   -0.0072      0.094     -0.076      0.940      -0.192       0.178
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.1471      0.129     -1.142      0.253      -0.399       0.105
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     -0.4076      0.373     -1.092      0.275      -1.139       0.324
# Information on the annual meeting/Information on OHBM behind-the-scenes (e.g. governance, financing)                                                    -0.6952      0.127     -5.482      0.000      -0.944      -0.447
# Information on OHBM behind-the-scenes (e.g. governance, financing)/Updates on OHBM committee / SIGs activities throughout the year                      -1.4698      0.104    -14.200      0.000      -1.673      -1.267
# Updates on OHBM committee / SIGs activities throughout the year/Reviews on OHBM activities                                                              -1.3629      0.091    -14.912      0.000      -1.542      -1.184
# Reviews on OHBM activities/Interviews with human brain mappers                                                                                          -1.5616      0.098    -15.919      0.000      -1.754      -1.369
# Interviews with human brain mappers/Tutorials on different topics related to human brain mapping                                                        -1.3572      0.087    -15.603      0.000      -1.528      -1.187
# Tutorials on different topics related to human brain mapping/Controversial topics in the field                                                          -0.9007      0.070    -12.877      0.000      -1.038      -0.764
# Controversial topics in the field/Exciting new science or developments in the brain mapping field                                                       -0.8130      0.076    -10.757      0.000      -0.961      -0.665
# ========================================================================================================================================================================================================================
# C(geographic_region, Treatment)[T.Europe]                                                                                                               1.175112
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          1.786011
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          1.152772
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  1.245427
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            1.139833
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    0.926356
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       0.930546
# C(career_stage, Treatment)[T.Masters student]                                                                                                           0.988333
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     0.774087
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   0.992863
# C(career_stage, Treatment)[T.Research staff]                                                                                                            0.863231
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     0.665212
# Information on the annual meeting/Information on OHBM behind-the-scenes (e.g. governance, financing)                                                    0.498992
# Information on OHBM behind-the-scenes (e.g. governance, financing)/Updates on OHBM committee / SIGs activities throughout the year                      0.229973
# Updates on OHBM committee / SIGs activities throughout the year/Reviews on OHBM activities                                                              0.255924
# Reviews on OHBM activities/Interviews with human brain mappers                                                                                          0.209800
# Interviews with human brain mappers/Tutorials on different topics related to human brain mapping                                                        0.257386
# Tutorials on different topics related to human brain mapping/Controversial topics in the field                                                          0.406289
# Controversial topics in the field/Exciting new science or developments in the brain mapping field                                                       0.443508
# dtype: float64

# %%
# now let's run some basic analyses to check against SurveyMonkey outputs
responses['is_member'].value_counts(normalize=True)

responses['geographic_region'].value_counts(normalize=True)

responses['career_stage'].value_counts(normalize=True)

# for the other questions, we can load in our sidecar JSON
# with question-level metadata
with open('levels.json') as f:
    queries = json.load(f)

print(f'There are {len(queries.keys())} questions to consider.') 
print(queries.keys())

question = 'job_board_access'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'job_board_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'email_access'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'email_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'blog_access'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'blog_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'twitter_access'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'twitter_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'podcast_access'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'podcast_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'facebook_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'youtube_access'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'youtube_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'linkedin_access'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'linkedin_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'ondemand_access'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'ondemand_content'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'content_platform'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'sig_platform'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())

question = 'content_importance'
scale_values = queries[question]

res = fit_model(responses, question, scale_values)
print(res.summary())
# Out:
# There are 20 questions to consider.
# dict_keys(['job_board_access', 'job_board_content', 'email_access', 'email_content', 'blog_access', 'blog_content', 'twitter_access', 'twitter_content', 'podcast_access', 'podcast_content', 'facebook_content', 'youtube_access', 'youtube_content', 'linkedin_access', 'linkedin_content', 'ondemand_access', 'ondemand_content', 'content_platform', 'sig_platform', 'content_importance'])
# Optimization terminated successfully.
#          Current function value: 1.071704
#          Iterations: 56
#          Function evaluations: 57
#          Gradient evaluations: 57
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:       job_board_access   Log-Likelihood:                -327.94
# Model:                   OrderedModel   AIC:                             685.9
# Method:            Maximum Likelihood   BIC:                             741.7
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:10
# No. Observations:                 306
# Df Residuals:                     291
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                               -0.2405      0.212     -1.135      0.256      -0.656       0.175
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          -0.3899      0.658     -0.593      0.554      -1.680       0.900
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          -0.2695      0.217     -1.240      0.215      -0.696       0.157
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.5670      0.414      1.370      0.171      -0.244       1.378
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             1.1642      0.466      2.499      0.012       0.251       2.077
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.9569      0.230      4.160      0.000       0.506       1.408
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        1.1112      0.190      5.857      0.000       0.739       1.483
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.3992      0.457     -0.874      0.382      -1.295       0.496
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.6375      0.430      1.481      0.139      -0.206       1.481
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.6488      0.213      3.041      0.002       0.231       1.067
# C(career_stage, Treatment)[T.Research staff]                                                                                                             1.0834      0.250      4.325      0.000       0.592       1.574
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.1790      0.565      0.317      0.751      -0.928       1.286
# I didn't know OHBM had a job board/I know about the OHBM job board but I don't use it                                                                    0.2900      0.227      1.275      0.202      -0.156       0.736
# I know about the OHBM job board but I don't use it/I look at the OHBM job board ocassionally                                                            -0.0510      0.088     -0.581      0.561      -0.223       0.121
# I look at the OHBM job board ocassionally/I look at the OHBM job board regularly                                                                         0.2799      0.117      2.382      0.017       0.050       0.510
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 1.151657
#          Iterations: 62
#          Function evaluations: 63
#          Gradient evaluations: 63
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:      job_board_content   Log-Likelihood:                -263.73
# Model:                   OrderedModel   AIC:                             557.5
# Method:            Maximum Likelihood   BIC:                             609.0
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:11
# No. Observations:                 229
# Df Residuals:                     214
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                               -0.1121      0.232     -0.483      0.629      -0.567       0.343
# C(geographic_region, Treatment)[T.Middle East]                                                                                                          -0.6107      0.634     -0.963      0.335      -1.853       0.632
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.1100      0.235      0.468      0.640      -0.351       0.571
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.6696      0.500      1.338      0.181      -0.311       1.650
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.9207      0.600      1.534      0.125      -0.256       2.097
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    -0.5024      0.254     -1.976      0.048      -1.001      -0.004
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       -0.5042      0.207     -2.435      0.015      -0.910      -0.098
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.6856      0.519     -1.322      0.186      -1.702       0.331
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     -0.7151      0.439     -1.629      0.103      -1.576       0.145
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   -0.2466      0.245     -1.006      0.314      -0.727       0.234
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.3419      0.270     -1.265      0.206      -0.872       0.188
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     -1.6168      0.705     -2.295      0.022      -2.998      -0.236
# Postings are not relevant to me/Postings are somewhat relevant                                                                                          -0.9180      0.246     -3.725      0.000      -1.401      -0.435
# Postings are somewhat relevant/Postings are relevant when related to the Annual Meeting                                                                  0.3037      0.080      3.795      0.000       0.147       0.461
# Postings are relevant when related to the Annual Meeting/Postings are very relevant throughout the year                                                 -1.2616      0.231     -5.452      0.000      -1.715      -0.808
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 0.835409
#          Iterations: 63
#          Function evaluations: 64
#          Gradient evaluations: 64
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:           email_access   Log-Likelihood:                -257.31
# Model:                   OrderedModel   AIC:                             544.6
# Method:            Maximum Likelihood   BIC:                             600.6
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:12
# No. Observations:                 308
# Df Residuals:                     293
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.0250      0.228      0.110      0.913      -0.423       0.473
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           1.1968      0.782      1.531      0.126      -0.335       2.729
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          -0.4590      0.233     -1.972      0.049      -0.915      -0.003
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.6711      0.489      1.373      0.170      -0.287       1.629
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.8471      0.533      1.589      0.112      -0.198       1.892
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.0408      0.233      0.175      0.861      -0.417       0.498
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.5257      0.193      2.718      0.007       0.147       0.905
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.8490      0.431     -1.971      0.049      -1.693      -0.005
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.3917      0.458      0.855      0.393      -0.507       1.290
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.2685      0.210      1.279      0.201      -0.143       0.680
# C(career_stage, Treatment)[T.Research staff]                                                                                                             0.6218      0.267      2.331      0.020       0.099       1.145
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.2835      0.532      0.533      0.594      -0.759       1.326
# I don't get emails from OHBM/I get emails from OHBM but I don't read them                                                                               -1.7037      0.257     -6.627      0.000      -2.208      -1.200
# I get emails from OHBM but I don't read them/I get emails from OHBM and I occasionally read them                                                        -2.2766      0.568     -4.005      0.000      -3.391      -1.163
# I get emails from OHBM and I occasionally read them/I get emails from OHBM and I always read them                                                        0.6145      0.073      8.407      0.000       0.471       0.758
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 1.274311
#          Iterations: 53
#          Function evaluations: 54
#          Gradient evaluations: 54
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:          email_content   Log-Likelihood:                -391.21
# Model:                   OrderedModel   AIC:                             814.4
# Method:            Maximum Likelihood   BIC:                             874.1
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:13
# No. Observations:                 307
# Df Residuals:                     291
# Df Model:                          16
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.1884      0.204      0.922      0.357      -0.212       0.589
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.0313      0.577      0.054      0.957      -1.099       1.162
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.0739      0.210      0.352      0.725      -0.337       0.485
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                  -0.0982      0.404     -0.243      0.808      -0.891       0.694
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.7402      0.449      1.647      0.100      -0.141       1.621
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    -0.0300      0.216     -0.139      0.889      -0.453       0.393
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.3437      0.174      1.970      0.049       0.002       0.686
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.4968      0.392     -1.266      0.206      -1.266       0.272
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.0436      0.406      0.107      0.914      -0.752       0.839
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.2160      0.192      1.125      0.261      -0.160       0.592
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.0051      0.235     -0.022      0.983      -0.466       0.455
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     -0.4942      0.503     -0.982      0.326      -1.480       0.492
# I don’t know / NA/It is not relevant to me                                                                                                              -1.3348      0.230     -5.807      0.000      -1.785      -0.884
# It is not relevant to me/It is somewhat relevant                                                                                                        -1.7909      0.368     -4.864      0.000      -2.513      -1.069
# It is somewhat relevant/It is very relevant only when related to the annual meeting                                                                      0.4065      0.073      5.538      0.000       0.263       0.550
# It is very relevant only when related to the annual meeting/It is very relevant throughout the year                                                     -0.3377      0.103     -3.291      0.001      -0.539      -0.137
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 1.092577
#          Iterations: 52
#          Function evaluations: 53
#          Gradient evaluations: 53
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:            blog_access   Log-Likelihood:                -331.05
# Model:                   OrderedModel   AIC:                             692.1
# Method:            Maximum Likelihood   BIC:                             747.8
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:14
# No. Observations:                 303
# Df Residuals:                     288
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                               -0.1677      0.217     -0.773      0.439      -0.593       0.257
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.5422      0.609      0.890      0.374      -0.652       1.737
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                          -0.0451      0.222     -0.204      0.839      -0.479       0.389
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.0589      0.423      0.139      0.889      -0.770       0.888
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            -0.1372      0.479     -0.287      0.774      -1.075       0.801
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.7578      0.231      3.280      0.001       0.305       1.211
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.7726      0.191      4.048      0.000       0.399       1.147
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.2320      0.457     -0.508      0.611      -1.127       0.663
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.2225      0.445      0.501      0.617      -0.649       1.094
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.7866      0.212      3.711      0.000       0.371       1.202
# C(career_stage, Treatment)[T.Research staff]                                                                                                             0.6321      0.258      2.454      0.014       0.127       1.137
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.1851      0.569      0.325      0.745      -0.930       1.300
# I didn't know that OHBM had a blog/I know about the blog, but I don’t read it                                                                            0.4042      0.234      1.728      0.084      -0.054       0.863
# I know about the blog, but I don’t read it/I know about the blog and occasionally read the posts                                                        -0.3801      0.105     -3.625      0.000      -0.586      -0.175
# I know about the blog and occasionally read the posts/I know about the blog and regularly read the posts                                                 0.2521      0.114      2.215      0.027       0.029       0.475
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 0.912506
#          Iterations: 63
#          Function evaluations: 64
#          Gradient evaluations: 64
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:           blog_content   Log-Likelihood:                -271.01
# Model:                   OrderedModel   AIC:                             574.0
# Method:            Maximum Likelihood   BIC:                             633.1
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:16
# No. Observations:                 297
# Df Residuals:                     281
# Df Model:                          16
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.0277      0.247      0.112      0.911      -0.457       0.512
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.2290      0.709      0.323      0.747      -1.160       1.618
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.2473      0.247      1.001      0.317      -0.237       0.732
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.1570      0.496      0.317      0.752      -0.815       1.129
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            -0.2083      0.609     -0.342      0.732      -1.401       0.984
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.6872      0.259      2.649      0.008       0.179       1.196
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.6723      0.217      3.095      0.002       0.247       1.098
# C(career_stage, Treatment)[T.Masters student]                                                                                                            0.1340      0.507      0.264      0.792      -0.860       1.128
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.5247      0.458      1.145      0.252      -0.374       1.423
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.5922      0.240      2.470      0.014       0.122       1.062
# C(career_stage, Treatment)[T.Research staff]                                                                                                             0.5153      0.280      1.840      0.066      -0.034       1.064
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.1047      0.670      0.156      0.876      -1.209       1.419
# I don’t know / NA/It is not relevant to me                                                                                                               1.0284      0.266      3.865      0.000       0.507       1.550
# It is not relevant to me/It is somewhat relevant                                                                                                        -2.6715      0.373     -7.162      0.000      -3.403      -1.940
# It is somewhat relevant/It is very relevant only when related to the annual meeting                                                                     -0.4128      0.127     -3.254      0.001      -0.661      -0.164
# It is very relevant only when related to the annual meeting/It is very relevant throughout the year                                                     -3.3241      0.703     -4.731      0.000      -4.701      -1.947
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 1.267502
#          Iterations: 68
#          Function evaluations: 69
#          Gradient evaluations: 69
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:         twitter_access   Log-Likelihood:                -385.32
# Model:                   OrderedModel   AIC:                             802.6
# Method:            Maximum Likelihood   BIC:                             862.1
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:17
# No. Observations:                 304
# Df Residuals:                     288
# Df Model:                          16
# ====================================================================================================================================================================================================================================
#                                                                                                                                                                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                            0.3620      0.221      1.640      0.101      -0.071       0.795
# C(geographic_region, Treatment)[T.Middle East]                                                                                                                       0.3277      0.629      0.521      0.603      -0.906       1.561
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                                       0.6053      0.226      2.682      0.007       0.163       1.048
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                               1.6275      0.424      3.835      0.000       0.796       2.459
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                                         0.8409      0.459      1.832      0.067      -0.059       1.740
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]                 0.4326      0.220      1.963      0.050       0.001       0.865
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]                    0.1766      0.180      0.982      0.326      -0.176       0.529
# C(career_stage, Treatment)[T.Masters student]                                                                                                                       -0.6465      0.469     -1.380      0.168      -1.565       0.272
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                                 -0.1338      0.416     -0.322      0.748      -0.949       0.682
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                                0.6634      0.200      3.309      0.001       0.271       1.056
# C(career_stage, Treatment)[T.Research staff]                                                                                                                         0.2324      0.247      0.940      0.347      -0.252       0.717
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                                 -0.3959      0.675     -0.586      0.558      -1.719       0.928
# I don’t use Twitter / NA/I use Twitter but didn’t know that the OHBM Twitter account exists                                                                          0.2959      0.230      1.287      0.198      -0.155       0.746
# I use Twitter but didn’t know that the OHBM Twitter account exists/I use Twitter and know about OHBM Twitter, but I don’t follow the account                        -1.7960      0.228     -7.861      0.000      -2.244      -1.348
# I use Twitter and know about OHBM Twitter, but I don’t follow the account/I use Twitter, follow the OHBM Twitter account, and occasionally see their tweets         -1.9398      0.243     -7.973      0.000      -2.417      -1.463
# I use Twitter, follow the OHBM Twitter account, and occasionally see their tweets/I use Twitter, follow the OHBM Twitter account, and regularly see their tweets     0.1980      0.080      2.467      0.014       0.041       0.355
# ====================================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 1.219184
#          Iterations: 60
#          Function evaluations: 61
#          Gradient evaluations: 61
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:        twitter_content   Log-Likelihood:                -365.76
# Model:                   OrderedModel   AIC:                             763.5
# Method:            Maximum Likelihood   BIC:                             822.8
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:18
# No. Observations:                 300
# Df Residuals:                     284
# Df Model:                          16
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.2529      0.231      1.096      0.273      -0.199       0.705
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.7436      0.637      1.167      0.243      -0.506       1.993
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.5205      0.234      2.221      0.026       0.061       0.980
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   1.2348      0.437      2.828      0.005       0.379       2.090
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.9419      0.462      2.038      0.042       0.036       1.848
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.3412      0.225      1.519      0.129      -0.099       0.782
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.0710      0.188      0.378      0.705      -0.297       0.439
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.6930      0.512     -1.354      0.176      -1.697       0.310
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     -0.3163      0.430     -0.735      0.462      -1.159       0.527
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.5257      0.203      2.588      0.010       0.128       0.924
# C(career_stage, Treatment)[T.Research staff]                                                                                                             0.2005      0.252      0.797      0.426      -0.293       0.694
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.0471      0.605      0.078      0.938      -1.138       1.232
# I don’t know / NA/It is not relevant to me                                                                                                               0.4491      0.240      1.870      0.062      -0.022       0.920
# It is not relevant to me/It is somewhat relevant                                                                                                        -2.7666      0.373     -7.410      0.000      -3.498      -2.035
# It is somewhat relevant/It is very relevant only when related to the annual meeting                                                                     -0.1805      0.096     -1.888      0.059      -0.368       0.007
# It is very relevant only when related to the annual meeting/It is very relevant throughout the year                                                     -1.2739      0.208     -6.112      0.000      -1.682      -0.865
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 0.887636
#          Iterations: 78
#          Function evaluations: 79
#          Gradient evaluations: 79
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:         podcast_access   Log-Likelihood:                -269.84
# Model:                   OrderedModel   AIC:                             569.7
# Method:            Maximum Likelihood   BIC:                             625.4
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:20
# No. Observations:                 304
# Df Residuals:                     289
# Df Model:                          15
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.0694      0.264      0.263      0.793      -0.448       0.587
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.6164      0.633      0.974      0.330      -0.624       1.856
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.5561      0.261      2.131      0.033       0.045       1.067
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   1.2289      0.433      2.836      0.005       0.380       2.078
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.5521      0.503      1.097      0.273      -0.434       1.539
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.3165      0.257      1.234      0.217      -0.186       0.819
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.3369      0.209      1.613      0.107      -0.073       0.746
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.2315      0.510     -0.454      0.650      -1.232       0.768
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                      0.0003      0.494      0.001      0.999      -0.968       0.968
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.4272      0.228      1.877      0.060      -0.019       0.873
# C(career_stage, Treatment)[T.Research staff]                                                                                                             0.5471      0.272      2.008      0.045       0.013       1.081
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     -3.5380     65.936     -0.054      0.957    -132.771     125.695
# I didn't know that OHBM had a podcast/I know about the podcast, but I don’t listen to it                                                                 1.0334      0.280      3.690      0.000       0.484       1.582
# I know about the podcast, but I don’t listen to it/I know about the podcast and occasionally listen to the episodes                                     -0.7130      0.141     -5.054      0.000      -0.989      -0.436
# I know about the podcast and occasionally listen to the episodes/I know about the podcast and regularly listen to the episodes                          -0.0817      0.143     -0.570      0.569      -0.363       0.199
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 0.772918
#          Iterations: 95
#          Function evaluations: 96
#          Gradient evaluations: 96
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:        podcast_content   Log-Likelihood:                -231.10
# Model:                   OrderedModel   AIC:                             494.2
# Method:            Maximum Likelihood   BIC:                             553.4
# Date:                Fri, 19 Jan 2024
# ...
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.6749      0.237      2.848      0.004       0.210       1.139
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.1525      0.129      1.180      0.238      -0.101       0.406
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.1018      0.107      0.955      0.340      -0.107       0.311
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.3709      0.290     -1.280      0.201      -0.939       0.197
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     -0.0664      0.259     -0.256      0.798      -0.574       0.441
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.1095      0.116      0.944      0.345      -0.118       0.337
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.0041      0.154     -0.026      0.979      -0.306       0.298
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      0.1222      0.365      0.335      0.738      -0.593       0.837
# OHBM website (https://www.humanbrainmapping.org)/Official OHBM Emails (*@humanbrainmapping.org emails)                                                  -0.1094      0.147     -0.743      0.458      -0.398       0.179
# Official OHBM Emails (*@humanbrainmapping.org emails)/Blog (https://www.ohbmbrainmappingblog.com)                                                       -0.3603      0.061     -5.910      0.000      -0.480      -0.241
# Blog (https://www.ohbmbrainmappingblog.com)/Twitter (https://twitter.com/OHBM)                                                                          -1.8961      0.147    -12.940      0.000      -2.183      -1.609
# Twitter (https://twitter.com/OHBM)/NeuroSalience podcast (https://anchor.fm/ohbm)                                                                       -0.6041      0.079     -7.620      0.000      -0.760      -0.449
# NeuroSalience podcast (https://anchor.fm/ohbm)/Facebook (https://www.facebook.com/humanbrainmapping.org)                                                -1.6720      0.166    -10.059      0.000      -1.998      -1.346
# Facebook (https://www.facebook.com/humanbrainmapping.org)/Youtube (https://www.youtube.com/channel/UCwMM4wEFi_hx2_6wVVoPBJA)                            -3.1257      0.375     -8.334      0.000      -3.861      -2.391
# Youtube (https://www.youtube.com/channel/UCwMM4wEFi_hx2_6wVVoPBJA)/LinkedIn (https://www.linkedin.com/company/organization-for-human-brain-mapping)     -2.6035      0.298     -8.745      0.000      -3.187      -2.020
# LinkedIn (https://www.linkedin.com/company/organization-for-human-brain-mapping)/OHBM OnDemand (https://www.pathlms.com/ohbm)                           -3.5508      0.498     -7.137      0.000      -4.526      -2.576
# OHBM OnDemand (https://www.pathlms.com/ohbm)/OHBM Job Board                                                                                             -0.8716      0.146     -5.984      0.000      -1.157      -0.586
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 1.805081
#          Iterations: 82
#          Function evaluations: 83
#          Gradient evaluations: 83
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:           sig_platform   Log-Likelihood:                -501.81
# Model:                   OrderedModel   AIC:                             1042.
# Method:            Maximum Likelihood   BIC:                             1111.
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:38
# No. Observations:                 278
# Df Residuals:                     259
# Df Model:                          19
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.0042      0.254      0.016      0.987      -0.495       0.503
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.6121      1.291      0.474      0.635      -1.918       3.142
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.0967      0.255      0.380      0.704      -0.402       0.596
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.1803      0.352      0.512      0.609      -0.510       0.871
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                            -0.3050      0.455     -0.670      0.503      -1.197       0.587
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]     0.0865      0.220      0.394      0.693      -0.344       0.517
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]        0.0757      0.206      0.368      0.713      -0.328       0.480
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.1338      0.423     -0.316      0.752      -0.964       0.696
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     -0.3045      0.786     -0.387      0.699      -1.845       1.236
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                    0.1079      0.178      0.606      0.544      -0.241       0.457
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.1731      0.299     -0.578      0.563      -0.760       0.414
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                      1.0367      0.765      1.356      0.175      -0.462       2.535
# BrainArt Twitter (https://twitter.com/OHBM_BrainArt)/BrainArt Instagram (https://www.instagram.com/ohbm_basig)                                          -0.7084      0.271     -2.615      0.009      -1.239      -0.178
# BrainArt Instagram (https://www.instagram.com/ohbm_basig)/Open Science Twitter (https://twitter.com/OhbmOpen)                                           -1.8001      0.259     -6.938      0.000      -2.309      -1.292
# Open Science Twitter (https://twitter.com/OhbmOpen)/Student-Postdoc Blog (https://www.ohbmtrainees.com/sig-blog)                                        -0.2967      0.101     -2.938      0.003      -0.495      -0.099
# Student-Postdoc Blog (https://www.ohbmtrainees.com/sig-blog)/Student-Postdoc Facebook (https://www.facebook.com/OHBMStudentandPostdocSection)           -1.5390      0.200     -7.683      0.000      -1.932      -1.146
# Student-Postdoc Facebook (https://www.facebook.com/OHBMStudentandPostdocSection)/Student-Postdoc Twitter (https://twitter.com/OHBM_Trainees)            -2.8466      0.404     -7.050      0.000      -3.638      -2.055
# Student-Postdoc Twitter (https://twitter.com/OHBM_Trainees)/Sustainability Blog (https://ohbm-environment.org/blog)                                     -0.3727      0.119     -3.133      0.002      -0.606      -0.140
# Sustainability Blog (https://ohbm-environment.org/blog)/Sustainability Twitter (https://twitter.com/OhbmEnvironment)                                    -1.7549      0.307     -5.711      0.000      -2.357      -1.153
# ========================================================================================================================================================================================================================
# Optimization terminated successfully.
#          Current function value: 2.012973
#          Iterations: 64
#          Function evaluations: 65
#          Gradient evaluations: 65
#                              OrderedModel Results
# ==============================================================================
# Dep. Variable:     content_importance   Log-Likelihood:                -2375.3
# Model:                   OrderedModel   AIC:                             4789.
# Method:            Maximum Likelihood   BIC:                             4885.
# Date:                Fri, 19 Jan 2024
# Time:                        14:58:44
# No. Observations:                1180
# Df Residuals:                    1161
# Df Model:                          19
# ========================================================================================================================================================================================================================
#                                                                                                                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# C(geographic_region, Treatment)[T.Europe]                                                                                                                0.1614      0.119      1.357      0.175      -0.072       0.394
# C(geographic_region, Treatment)[T.Middle East]                                                                                                           0.5800      0.312      1.857      0.063      -0.032       1.192
# C(geographic_region, Treatment)[T.North America (Including Canada and Mexico)]                                                                           0.1422      0.119      1.193      0.233      -0.091       0.376
# C(geographic_region, Treatment)[T.Oceania (Australia and New Zealand)]                                                                                   0.2195      0.182      1.207      0.227      -0.137       0.576
# C(geographic_region, Treatment)[T.South America (Including Central America)]                                                                             0.1309      0.220      0.594      0.552      -0.301       0.562
# C(career_stage, Treatment)[T.Early-career faculty member / group leader / principal investigator (i.e., less than 5 years from initial appointment)]    -0.0765      0.105     -0.727      0.467      -0.283       0.130
# C(career_stage, Treatment)[T.Established faculty member / group leader / principal investigator (i.e., 5 or more years from initial appointment)]       -0.0720      0.085     -0.846      0.397      -0.239       0.095
# C(career_stage, Treatment)[T.Masters student]                                                                                                           -0.0117      0.208     -0.056      0.955      -0.420       0.397
# C(career_stage, Treatment)[T.Non-academic position]                                                                                                     -0.2561      0.205     -1.251      0.211      -0.657       0.145
# C(career_stage, Treatment)[T.Postdoctoral researcher]                                                                                                   -0.0072      0.094     -0.076      0.940      -0.192       0.178
# C(career_stage, Treatment)[T.Research staff]                                                                                                            -0.1471      0.129     -1.142      0.253      -0.399       0.105
# C(career_stage, Treatment)[T.Undergraduate student]                                                                                                     -0.4076      0.373     -1.092      0.275      -1.139       0.324
# Information on the annual meeting/Information on OHBM behind-the-scenes (e.g. governance, financing)                                                    -0.6952      0.127     -5.482      0.000      -0.944      -0.447
# Information on OHBM behind-the-scenes (e.g. governance, financing)/Updates on OHBM committee / SIGs activities throughout the year                      -1.4698      0.104    -14.200      0.000      -1.673      -1.267
# Updates on OHBM committee / SIGs activities throughout the year/Reviews on OHBM activities                                                              -1.3629      0.091    -14.912      0.000      -1.542      -1.184
# Reviews on OHBM activities/Interviews with human brain mappers                                                                                          -1.5616      0.098    -15.919      0.000      -1.754      -1.369
# Interviews with human brain mappers/Tutorials on different topics related to human brain mapping                                                        -1.3572      0.087    -15.603      0.000      -1.528      -1.187
# Tutorials on different topics related to human brain mapping/Controversial topics in the field                                                          -0.9007      0.070    -12.877      0.000      -1.038      -0.764
# Controversial topics in the field/Exciting new science or developments in the brain mapping field                                                       -0.8130      0.076    -10.757      0.000      -0.961      -0.665
# ========================================================================================================================================================================================================================
